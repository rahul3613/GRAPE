# %%
import os.path as osp
import inspect

# %%
uji_path = osp.dirname(osp.abspath(inspect.getfile(inspect.currentframe())))

# %%
uji_path
# Out:
# 'C:\\Users\\rahul\\AppData\\Local\\Temp\\ipykernel_11916'

# %%
import pandas as pd

# %%
pd.read_csv("C:/Users/rahul/Desktop/GRAPE/uji/raw_data/UJIndoorLoc/trainingData.csv")
# Out:
#        WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0         100     100     100     100     100     100     100     100     100
# 1         100     100     100     100     100     100     100     100     100
# 2         100     100     100     100     100     100     100     -97     100
# 3         100     100     100     100     100     100     100     100     100
# 4         100     100     100     100     100     100     100     100     100
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 19932     100     100     100     100     100     100     100     100     100
# 19933     100     100     100     100     100     100     100     100     100
# 19934     100     100     100     100     100     100     100     100     100
# 19935     100     100     100     100     100     100     100     100     100
# 19936     100     100     100     100     100     100     100     100     100
#
# ...

# %%
df_train = pd.read_csv("C:/Users/rahul/Desktop/GRAPE/uji/raw_data/UJIndoorLoc/data/trainingData.csv")
df_val = pd.read_csv("C:/Users/rahul/Desktop/GRAPE/uji/raw_data/UJIndoorLoc/data/trainingData.csv")
df = pd.concat([df_train, df_val])

building_id = 1
floor= 1
df = df.loc[(df_train['BUILDINGID'] == building_id) & (df_train['FLOOR'] == floor)]
df_X = df.iloc[: , :520]
# Preprocessing
df_X += 104
df_X[df_X == 204] = 0.0
df_X

df_y = df[["LONGITUDE"]]

# %%
len(df_y.LONGITUDE.shape)
# Out:
# 1

# %%
len(df_y.shape)
# Out:
# 2

# %%
df_y.to_numpy()
# Out:
# array([[-7458.3811],
#        [-7466.9637],
#        [-7458.0493],
#        ...,
#        [-7469.8892],
#        [-7466.9637],
#        [-7469.8715]])
